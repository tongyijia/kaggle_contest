# %%
import pandas as pd
import numpy as np

from scipy import stats
#from mlxtend.preprocessing import minmax_scaling

#plot
import seaborn as sns
import matplotlib.pyplot as plt

kickstarters_2017 = pd.read_csv("../data/ks-projects-201801.csv")

np.random.seed(0)

# %%
#数据缩放

original_data = np.random.exponential(size = 1000)

# mix-max scale the data between 0 and 1
scaled_data = minmax_scaling(original_data, columns = [0])

# plot both together to compare
fig, ax=plt.subplots(1,2)
sns.distplot(original_data, ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(scaled_data, ax=ax[1])
ax[1].set_title("Scaled data")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-016fd4e1dabc> in <module>()
#       2
#       3 # mix-max scale the data between 0 and 1
# ----> 4 scaled_data = minmax_scaling(original_data, columns = [0])
#       5
#       6 # plot both together to compare
#
# NameError: name 'minmax_scaling' is not defined

# %%
goal = kickstarters_2017.goal
scaled_goal = minmax_scaling(goal, columns=[0])

fig, ax = plt.subplots(1,2)
sns.distplot(goal, ax=ax[0])
ax[0].set_title('Original data')
sns.distplot(scaled_goal, ax=ax[1])
ax[1].set_title('Scaled data')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5792cedab0b2> in <module>()
#       1 goal = kickstarters_2017.goal
# ----> 2 scaled_goal = minmax_scaling(goal, columns=[0])
#       3
#       4 fig, ax = plt.subplots(1,2)
#       5 sns.distplot(goal, ax=ax[0])
#
# NameError: name 'minmax_scaling' is not defined

# %%
#数据标准化

# generate 1000 data points randomly drawn from an exponential distribution
original_data = np.random.exponential(size = 1000)

# normalize the exponential data with boxcox
normalized_data = stats.boxcox(original_data)

# plot both together to compare
fig, ax=plt.subplots(1,2)
sns.distplot(original_data, ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(normalized_data[0], ax=ax[1])
ax[1].set_title("Normalized data")
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'Normalized data')

# %%
pos_indexes = kickstarters_2017.pledged > 0
vals = kickstarters_2017.pledged.loc[pos_indexes]
scaled_vals = stats.boxcox(vals)[0]

ig, ax=plt.subplots(1,2)
sns.distplot(vals, ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(scaled_vals, ax=ax[1])
ax[1].set_title("Normalized data")
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'Normalized data')

# %%
#
